# %%
import pandas as pd
import pyreadstat as prs

# %%
df, meta = prs.read_xport('../data/raw/NHANES Dietary Data/DR1IFF_L.xpt', output_format="pandas")
# Out:
# ---------------------------------------------------------------------------
# PyreadstatError                           Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 df, meta = prs.read_xport('../data/raw/NHANES Dietary Data/DR1IFF_L.xpt', output_format="pandas")
#
# File pyreadstat/pyreadstat.pyx:205, in pyreadstat.pyreadstat.read_xport()
#
# File pyreadstat/_readstat_parser.pyx:1195, in pyreadstat._readstat_parser.run_conversion()
#
# PyreadstatError: File ../data/raw/NHANES Dietary Data/DR1IFF_L.xpt does not exist!
